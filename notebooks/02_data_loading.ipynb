# %%
import pandas as pd

# %% [markdown]
# #### CSV Files Operation

# %%
data = {
    "ID": [1, 2, 3, 4, 5, 6, 7, 8],
    "Name": ["Ram", "Sita", "Gita", "Hari", "Nita", "Aman", "Rita", "Kiran"],
    "Age": [21, 22, 20, 23, 21, 24, 22, 23],
    "Gender": ["M", "F", "F", "M", "F", "M", "F", "M"],
    "Marks_Math": [78, 85, 69, 90, 74, 88, 81, 76],
    "Marks_Science": [82, 88, 72, 91, 79, 87, 84, 80],
    "Marks_English": [75, 80, 70, 85, 73, 82, 78, 77],
    "Result": ["Pass", "Pass", "Pass", "Pass", "Pass", "Pass", "Pass", "Pass"]
}

df = pd.DataFrame(data)
df
# Out:
#    ID   Name  Age Gender  Marks_Math  Marks_Science  Marks_English Result
# 0   1    Ram   21      M          78             82             75   Pass
# 1   2   Sita   22      F          85             88             80   Pass
# 2   3   Gita   20      F          69             72             70   Pass
# 3   4   Hari   23      M          90             91             85   Pass
# 4   5   Nita   21      F          74             79             73   Pass
# 5   6   Aman   24      M          88             87             82   Pass
# 6   7   Rita   22      F          81             84             78   Pass
# 7   8  Kiran   23      M          76             80             77   Pass

# %% [markdown]
# ## Handling CSV Files

# %% [markdown]
# #### Saving file as csv

# %%
file_path = '/home/prajwalmac/data_science_self/pandas_self/data/sample_data.csv'

# at default index also gets saved but if we dont want to sace index we can add index=False
df.to_csv(file_path,index=False)

# %% [markdown]
# #### Loading CSV file

# %%
file_path = '/home/prajwalmac/data_science_self/pandas_self/data/sample_data.csv'

load_csv = pd.read_csv(file_path)

load_csv
# Out:
#    ID   Name  Age Gender  Marks_Math  Marks_Science  Marks_English Result
# 0   1    Ram   21      M          78             82             75   Pass
# 1   2   Sita   22      F          85             88             80   Pass
# 2   3   Gita   20      F          69             72             70   Pass
# 3   4   Hari   23      M          90             91             85   Pass
# 4   5   Nita   21      F          74             79             73   Pass
# 5   6   Aman   24      M          88             87             82   Pass
# 6   7   Rita   22      F          81             84             78   Pass
# 7   8  Kiran   23      M          76             80             77   Pass

# %% [markdown]
# ## Handling Excel files

# %%
data = {
    "ID": [1, 2, 3, 4, 5, 6, 7, 8],
    "Name": ["Ram", "Sita", "Gita", "Hari", "Nita", "Aman", "Rita", "Kiran"],
    "Age": [21, 22, 20, 23, 21, 24, 22, 23],
    "Gender": ["M", "F", "F", "M", "F", "M", "F", "M"],
    "Marks_Math": [78, 85, 69, 90, 74, 88, 81, 76],
    "Marks_Science": [82, 88, 72, 91, 79, 87, 84, 80],
    "Marks_English": [75, 80, 70, 85, 73, 82, 78, 77],
    "Result": ["Pass", "Pass", "Pass", "Pass", "Pass", "Pass", "Pass", "Pass"]
}

df = pd.DataFrame(data)

df
# Out:
#    ID   Name  Age Gender  Marks_Math  Marks_Science  Marks_English Result
# 0   1    Ram   21      M          78             82             75   Pass
# 1   2   Sita   22      F          85             88             80   Pass
# 2   3   Gita   20      F          69             72             70   Pass
# 3   4   Hari   23      M          90             91             85   Pass
# 4   5   Nita   21      F          74             79             73   Pass
# 5   6   Aman   24      M          88             87             82   Pass
# 6   7   Rita   22      F          81             84             78   Pass
# 7   8  Kiran   23      M          76             80             77   Pass

# %% [markdown]
# #### Saving file as excel

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
filepath = '/home/prajwalmac/data_science_self/pandas_self/data/sample_excel_data.xlsx'

df.to_excel(filepath,index=False)

# %% [markdown]
# #### Loading excel files

# %%
filepath = '/home/prajwalmac/data_science_self/pandas_self/data/sample_excel_data.xlsx'

load_excel = pd.read_excel(filepath)

load_csv
# Out:
#    ID   Name  Age Gender  Marks_Math  Marks_Science  Marks_English Result
# 0   1    Ram   21      M          78             82             75   Pass
# 1   2   Sita   22      F          85             88             80   Pass
# 2   3   Gita   20      F          69             72             70   Pass
# 3   4   Hari   23      M          90             91             85   Pass
# 4   5   Nita   21      F          74             79             73   Pass
# 5   6   Aman   24      M          88             87             82   Pass
# 6   7   Rita   22      F          81             84             78   Pass
# 7   8  Kiran   23      M          76             80             77   Pass

# %% [markdown]
# ## Handling JSON files

# %% [markdown]
# #### Saving file as JSON

# %%
json_file_path =  '/home/prajwalmac/data_science_self/pandas_self/data/sample_json_data.json'

df.to_json(json_file_path,index=False)

# %% [markdown]
# #### Loading JSON File

# %%
json_file_path =  '/home/prajwalmac/data_science_self/pandas_self/data/sample_json_data.json'

pd.read_json(json_file_path)
# Out:
#    ID   Name  Age Gender  Marks_Math  Marks_Science  Marks_English Result
# 0   1    Ram   21      M          78             82             75   Pass
# 1   2   Sita   22      F          85             88             80   Pass
# 2   3   Gita   20      F          69             72             70   Pass
# 3   4   Hari   23      M          90             91             85   Pass
# 4   5   Nita   21      F          74             79             73   Pass
# 5   6   Aman   24      M          88             87             82   Pass
# 6   7   Rita   22      F          81             84             78   Pass
# 7   8  Kiran   23      M          76             80             77   Pass
