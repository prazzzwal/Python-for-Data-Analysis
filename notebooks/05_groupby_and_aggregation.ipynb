# %%
import pandas as pd

df = pd.read_csv("/home/prajwalmac/data_science_self/pandas_self/datasets/Pokemon.csv")
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
df = df.drop(columns='#')
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### groupby()

# %%
type1_group = df.groupby('Type 1')
type1_group

# %%
len(type1_group)
# Out:
# 18

# %%
type1_group.size().sort_values(ascending=False)
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Ground       32
# Dragon       32
# Ghost        32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# dtype: int64

# %%
#return first pokemon from each type
type1_group.first()
# Out:
#                              Name    Type 2  Total  HP  Attack  Defense  \
# Type 1
# Bug                      Caterpie    Flying    195  45      30       35
# Dark                      Umbreon    Flying    525  95      65      110
# Dragon                    Dratini    Flying    300  41      64       45
# Electric                  Pikachu     Steel    320  35      55       40
# Fairy                    Clefairy    Flying    323  70      45       48
# Fighting                   Mankey   Psychic    305  40      80       35
# Fire                   Charmander    Flying    309  39      52       43
# Flying    TornadusIncarnate Forme    Dragon    580  79     115       70
# Ghost                      Gastly    Poison    310  30      35       30
# Grass                   Bulbasaur    Poison    318  45      49       49
# Ground                  Sandshrew      Rock    300  50      75       85
# Ice                          Jynx   Psychic    455  65      50       35
# ...

# %%
#return first pokemon from each type
type1_group.last()
# Out:
#                            Name    Type 2  Total   HP  Attack  Defense  \
# Type 1
# Bug                    Vivillon    Flying    411   80      52       50
# Dark                    Yveltal    Flying    680  126     131       95
# Dragon         Zygarde50% Forme    Ground    600  108     100      121
# Electric                Dedenne     Fairy    431   67      58       57
# Fairy                   Xerneas    Flying    680  126     131       95
# Fighting               Hawlucha    Flying    500   78      92       75
# Fire                  Volcanion     Water    600   80     110      120
# Flying                  Noivern    Dragon    535   85      70       80
# Ghost       GourgeistSuper Size     Grass    494   85     100      122
# Grass                    Gogoat  Fighting    531  123     100       62
# Ground    LandorusTherian Forme    Flying    600   89     145       90
# Ice                     Avalugg     Ghost    514   95     117      184
# ...

# %%
legendary = df.groupby(df["Legendary"]==True)

# %%
legendary

# %%
legendary.first()
# Out:
#                 Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# Legendary
# False      Bulbasaur  Grass  Poison    318  45      49       49       65
# True        Articuno    Ice  Flying    580  90      85      100       95
#
#            Sp. Def  Speed  Generation  Legendary
# Legendary
# False           65     45           1      False
# True           125     85           1       True

# %%
type1_group['Speed'].min().sort_values()
# Out:
# Type 1
# Bug          5
# Normal       5
# Grass       10
# Rock        10
# Ground      10
# Fairy       15
# Water       15
# Fire        20
# Psychic     20
# Ghost       20
# Dark        20
# Steel       23
# Poison      25
# Fighting    25
# Ice         25
# Electric    35
# Dragon      40
# Flying      55
# Name: Speed, dtype: int64

# %%
type1_group['Attack'].max().sort_values(ascending=False)
# Out:
# Type 1
# Psychic     190
# Bug         185
# Ground      180
# Dragon      180
# Rock        165
# Ghost       165
# Fire        160
# Normal      160
# Water       155
# Dark        150
# Steel       150
# Fighting    145
# Grass       132
# Fairy       131
# Ice         130
# Electric    123
# Flying      115
# Poison      106
# Name: Attack, dtype: int64

# %% [markdown]
# ## Aggregation

# %%
df['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Normal', 'Bug', 'Fairy', 'Fighting',
#        'Psychic', 'Steel', 'Dark', 'Rock', 'Poison', 'Electric', 'Dragon',
#        'Ghost', 'Ice', 'Flying'], dtype=object)

# %%
df['Type 1'].value_counts()
# Out:
# Type 1
# Ghost       10
# Rock         9
# Fairy        9
# Fire         7
# Steel        5
# Psychic      5
# Water        5
# Dragon       4
# Normal       4
# Grass        3
# Bug          3
# Fighting     3
# Dark         3
# Electric     3
# Poison       2
# Ice          2
# Flying       2
# Name: count, dtype: int64

# %%
## Finding mean of numeric data only from the dataframe

print(df.mean(numeric_only=True))
print("\n")
print(df.min(numeric_only=True))
# Out:
# Total         437.291139
# HP             68.329114
# Attack         75.620253
# Defense        76.139241
# Sp. Atk        74.898734
# Sp. Def        75.544304
# Speed          66.759494
# Generation      5.936709
# Legendary       0.101266
# dtype: float64
#
#
# Total           200
# HP               38
# Attack           22
# Defense          33
# Sp. Atk          27
# Sp. Def          25
# Speed            23
# Generation        1
# Legendary     False
# dtype: object

# %% [markdown]
# ## Pivot Table

# %%
import os
os.getcwd()
# Out:
# '/home/prajwalmac/data_science_self/pandas_self/notebooks'

# %%
sample = pd.read_csv('/home/prajwalmac/data_science_self/pandas_self/datasets/sample_data.csv')
sample
# Out:
#    ID   Name  Age Gender  Marks_Math  Marks_Science  Marks_English Result
# 0   1    Ram   21      M          78             82             75   Pass
# 1   2   Sita   22      F          85             88             80   Pass
# 2   3   Gita   20      F          69             72             70   Pass
# 3   4   Hari   23      M          90             91             85   Pass
# 4   5   Nita   21      F          74             79             73   Pass
# 5   6   Aman   24      M          88             87             82   Pass
# 6   7   Rita   22      F          81             84             78   Pass
# 7   8  Kiran   23      M          76             80             77   Pass

# %%
table = sample.pivot_table(index='Gender', columns='Marks_Math',values='Result',aggfunc=max)
table
# Out:
# /tmp/ipykernel_6898/3350249648.py:1: FutureWarning: The provided callable <built-in function max> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   table = sample.pivot_table(index='Gender', columns='Marks_Math',values='Result',aggfunc=max)
# Marks_Math    69    74    76    78    81    85    88    90
# Gender
# F           Pass  Pass   NaN   NaN  Pass  Pass   NaN   NaN
# M            NaN   NaN  Pass  Pass   NaN   NaN  Pass  Pass
